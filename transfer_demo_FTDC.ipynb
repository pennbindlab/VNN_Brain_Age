# %%
import os
os.getcwd()
# set Code_and_Data as the working directory
os.chdir('/home/sihags/Downloads/VNN_FTDC_exps/Code_and_Data/')

import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow


import Modules.VNN_archit as VNNarchit
import Utils.graphML as gml
import Utils.vnn_demo_utils as VNN_Transfer

# %%
# Training_set: Select the VNNs according to the dataset they were trained on. Choose among '100', '300', '500' for FTDC100, FTDC300, FTDC500 respectively
# Test_set: Select the dataset to which the VNNs are transferred to. Choose among '100', '300', '500' for FTDC100, FTDC300, FTDC500 respectively
# Example: VNN_Transfer.FTDC_transfer('100','300') provides the output for VNNs trained on FTDC100 and transferred to FTDC300


Training_set = '100'
Test_set = '100'

# Output for VNNs transferred from FTDC100 to FTDC100
yhat_100_100 = VNN_Transfer.FTDC_transfer(Training_set,Test_set)



Training_set = '300'
Test_set = '100'

# Output for VNNs transferred from FTDC300 to FTDC100
yhat_300_100 = VNN_Transfer.FTDC_transfer(Training_set,Test_set)



Training_set = '500'
Test_set = '100'
# Output for VNNs transferred from FTDC500 to FTDC100
yhat_500_100 = VNN_Transfer.FTDC_transfer(Training_set,Test_set)

# %%
# Plot outputs on the FTDC100 dataset (VNNs trained on FTDC100 vs VNNs trained on FTDC300)

plt.scatter(yhat_100_100, yhat_300_100)
plt.xlabel("Output from VNNs trained on FTDC100",fontsize=15)
plt.ylabel("Output from VNNs trained on FTDC300", fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.ylim((56, 80))
xpoints = ypoints = plt.ylim()
plt.plot(xpoints, ypoints, linestyle='--', color='k', lw=3, scalex=False, scaley=False) # Identity (x = y) line
plt.show() 
#plt.savefig('
